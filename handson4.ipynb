# %% [markdown]
# Problem Statement 4: Guess the Number Game
# Objective:
# Create a Python program that allows the user to play a number guessing game.
#
# Background:
# Guessing games are a fun way to learn how to handle loops, conditionals, and user input in programming. In this task, you will build a simple game where the computer randomly selects a number, and the user has to guess it within a certain number of attempts.
#
# Requirements:
#
# Input:
#
# The program should randomly select a number between 1 and 100 (inclusive).
# The user should be allowed to input their guesses.
# Process:
#
# The program should compare the user's guess to the randomly selected number.
# If the guess is too high, the program should inform the user that their guess was too high.
# If the guess is too low, the program should inform the user that their guess was too low.
# The user should be given a maximum of 10 attempts to guess the correct number.
# Output:
#
# If the user guesses correctly, the program should congratulate them and display the number of attempts taken.
# If the user fails to guess the number within 10 attempts, the program should reveal the correct number and end the game.
# Bonus Features :
#
# Track and display the user's previous guesses to help them avoid repeating the same guess.
# Allow the user to play multiple rounds and keep track of their score.

# %%
import random
def Guess_the_number():
    number = random.randint(1,100)
    previous = []
    #print(number)
    for i in range (0,10): 
        print (f'Trial {i+1}')
        print("Previouos guesses : ", previous)
        guess =int(input("Please guess a number between 1 and 100 (inclusive) :"))
        previous.append(guess)

        if guess == number: 
            print(f"Kudos, Congratulation! You were able to idnetify the number in Attempt {i+1}") 
            print()
            play = input("Having fun, what's to play again (press y to play else play any key)")
            if play == 'y':
                return Guess_the_number()
            else:
                print("Have fun ! Hope you will come again")
                return
        
        elif -10 <= guess - number <=10:
            print("Your guess is within 10 integer ")
            print(f"{9-i} attempts left")
            print()
        else : 
            print("Your guess is more than 10 integer away ")
            print(f"{9-i} attempts left")
            print()
    print("Sorry, you were not able to identify the number in given time")
    print("The number was:", number)
    play = input("Having fun, what's to play again (press y to play else play any key)")
    if play == 'y':
        return Guess_the_number()
    else:
        print("Have fun ! Hope you will come again")
        return

# %%
Guess_the_number()
# Out:
# 78
# Trial 1
# Previouos guesses :  []
# Your guess is within 10 integer
# 9 attempts left
#
# Trial 2
# Previouos guesses :  [70]
# Your guess is more than 10 integer away
# 8 attempts left
#
# Trial 3
# Previouos guesses :  [70, 60]
# Kudos, Congratulation! You were able to idnetify the number in Attempt 3
# 72
# Trial 1
# Previouos guesses :  []
# Kudos, Congratulation! You were able to idnetify the number in Attempt 1
# 30
# Trial 1
# Previouos guesses :  []
# Your guess is more than 10 integer away
# 9 attempts left
#
# Trial 2
# Previouos guesses :  [12]
# Your guess is more than 10 integer away
# 8 attempts left
#
# Trial 3
# Previouos guesses :  [12, 13]
# Your guess is more than 10 integer away
# 7 attempts left
#
# Trial 4
# Previouos guesses :  [12, 13, 14]
# Your guess is more than 10 integer away
# 6 attempts left
#
# Trial 5
# Previouos guesses :  [12, 13, 14, 15]
# Your guess is more than 10 integer away
# 5 attempts left
#
# Trial 6
# Previouos guesses :  [12, 13, 14, 15, 16]
# Your guess is more than 10 integer away
# 4 attempts left
#
# Trial 7
# Previouos guesses :  [12, 13, 14, 15, 16, 17]
# Your guess is more than 10 integer away
# 3 attempts left
#
# Trial 8
# Previouos guesses :  [12, 13, 14, 15, 16, 17, 18]
# Your guess is more than 10 integer away
# 2 attempts left
#
# Trial 9
# Previouos guesses :  [12, 13, 14, 15, 16, 17, 18, 19]
# Your guess is within 10 integer
# 1 attempts left
#
# Trial 10
# Previouos guesses :  [12, 13, 14, 15, 16, 17, 18, 19, 20]
# Your guess is within 10 integer
# 0 attempts left
#
# Sorry, you were not able to identify the number in given time
# The number was: 30
# 9
# Trial 1
# Previouos guesses :  []
# Kudos, Congratulation! You were able to idnetify the number in Attempt 1
# 91
# Trial 1
# Previouos guesses :  []
# Your guess is more than 10 integer away
# 9 attempts left
#
# Trial 2
# Previouos guesses :  [12]
# Your guess is more than 10 integer away
# 8 attempts left
#
# Trial 3
# Previouos guesses :  [12, 12]
# Your guess is more than 10 integer away
# 7 attempts left
#
# Trial 4
# Previouos guesses :  [12, 12, 12]
# Your guess is more than 10 integer away
# 6 attempts left
#
# Trial 5
# Previouos guesses :  [12, 12, 12, 13]
# Your guess is more than 10 integer away
# 5 attempts left
#
# Trial 6
# Previouos guesses :  [12, 12, 12, 13, 14]
# Your guess is more than 10 integer away
# 4 attempts left
#
# Trial 7
# Previouos guesses :  [12, 12, 12, 13, 14, 13]
# Your guess is more than 10 integer away
# 3 attempts left
#
# Trial 8
# Previouos guesses :  [12, 12, 12, 13, 14, 13, 4]
# Your guess is more than 10 integer away
# 2 attempts left
#
# Trial 9
# Previouos guesses :  [12, 12, 12, 13, 14, 13, 4, 5]
# Your guess is more than 10 integer away
# 1 attempts left
#
# Trial 10
# Previouos guesses :  [12, 12, 12, 13, 14, 13, 4, 5, 34]
# Your guess is more than 10 integer away
# 0 attempts left
#
# Sorry, you were not able to identify the number in given time
# The number was: 91
# Have fun ! Hope you will come again
